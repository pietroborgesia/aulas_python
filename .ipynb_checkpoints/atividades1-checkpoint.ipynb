# %% [markdown]
# Exercício 1
# Crie um programa que mostre na tela:

# %%
a = "Eu Estou aprenendo Python"
print(a)
# Out:
# Eu Estou aprenendo Python

# %% [markdown]
# Exercício 2
# Crie um programa que mostre:

# %%
nome = "Pietro"
cidade = "Senador Canedo"

meu_nome = "nome" 
cidade_moro = "cidade"

print("Meu nome é", nome)
print("Eu moro em", cidade)
# Out:
# Meu nome é Pietro
# Eu moro em Senador Canedo

# %% [markdown]
# Exercício 3
# Crie duas variáveis: nome_do_aluno e idade_do_aluno.
# Depois mostre na tela algo assim:

# %%
nome = "Pietro"
sobrenome = "Borges"
idade = "24"

print("Meu nome é", nome, sobrenome, "e tenho", idade, "anos")
# Out:
# Meu nome é Pietro Borges e tenho 24 anos

# %% [markdown]
# Exercício 4 (Desafio Extra)
# Crie três variáveis: cidade, estado e pais. E mostre:

# %%
cidade = "Senador Canedo"
estado = "Goias"
pais = "Brasil"

print("Eu moro em", cidade,",", estado,"-", pais)
# Out:
# Eu moro em Senador Canedo , Goias - Brasil

# %% [markdown]
# Crie um programa que:
# 1. Pergunte o nome do aluno.
# 2. Pergunte a cidade onde ele mora.
# 3. Mostre a frase:

# %%
entrada = input("Digite seu nome: ")
cidade = input("Qual cidade você reside? ")

print("Olá,", entrada, "você mora em", cidade)
# Out:
# Digite seu nome:  Pietro
# Qual cidade você reside?  Senador Canedo
# Olá, Pietro você mora em Senador Canedo
